# %%
print("Hello World!!!")
# Out:
# Hello World!!!

# %%
import seaborn as sns

# %%
import numby as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a18ade34e670> in <module>
# ----> 1 import numby as np
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'numby'

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")

# %%
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
current_palette1 = sns.color_palette()
sns.palplot(current_palette1)
plt.show()

# %%
current_palette2 = sns.color_palette()
sns.palplot(sns.color_palette("Greens"))
plt.show()

# %%
current_palette3 = sns.color_palette()
sns.palplot(sns.color_palette("BrBG", 7))
plt.show()

# %%
sns.distplot(tips['total_bill'])
plt.show()
# Out:
# C:\Users\Grace_gao\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['total_bill'], kde = False)
plt.show()
# Out:
# C:\Users\Grace_gao\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['total_bill'], hist = False)
plt.show()
# Out:
# C:\Users\Grace_gao\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['total_bill'], hist = False, kde = False)
plt.show()
# Out:
# C:\Users\Grace_gao\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(x="total_bill", y="tip", data=tips)
plt.snow()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-ac5084ee689a> in <module>
#       1 sns.jointplot(x="total_bill", y="tip", data=tips)
# ----> 2 plt.snow()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'snow'

# %%
sns.jointplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
sns.set_style("ticks")
sns.pairplot(tips)
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.boxplot(x=tips["total_bill"])
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.violinplot(x=tips["total_bill"])
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.barplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.pointplot(x="time", y="total_bill", data=tips)
plt.show()

# %%
sns.pointplot(x="time", y="total_bill", hue="smoker", data=tips)
plt.show()

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
sns.residplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
uniform_data = np.random.rand(10, 12)
sns.heatmap(uniform_data)
plt.show()

# %%
df1 = tips[['total_bill', 'tip', 'size']]

# %%
sns.clustermap(df1)
plt.show()

# %%
sns.FacetGrid(tips, col="time", row="smoker")
plt.show()

# %%
g = sns.FacetGrid(tips, col="time", row="smoker")
g = g.map(plt.hist, "total_bill")
plt.show()

# %%
g = sns.PairGrid(tips)
g = g.map(plt.scatter)
plt.show()

# %%
g = sns.PairGrid(tips)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)

g = g.plot(sns.regplot, sns.distplot)
# Out:
# C:\Users\Grace_gao\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-89e05db65b7f> in <module>
#       1 g = sns.JointGrid(x="total_bill", y="tip", data=tips)
#       2
# ----> 3 g = g.plot(sns.regplot, sns.distplot)
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in plot(self, joint_func, marginal_func, **kwargs)
#    1659
#    1660         """
# -> 1661         self.plot_marginals(marginal_func, **kwargs)
#    1662         self.plot_joint(joint_func, **kwargs)
#    1663         return self
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1733         plt.sca(self.ax_marg_y)
#    1734         if str(func.__module__).startswith("seaborn"):
# -> 1735             func(y=self.y, **kwargs)
#    1736         else:
#    1737             func(self.y, vertical=True, **kwargs)
#
# TypeError: distplot() got an unexpected keyword argument 'y'
